# %%
import pandas as pd
import numpy as np

# %%
data=[['Tom',22],['Nick',25],['Julia',22]]
df=pd.DataFrame(data,columns=['Names','Age'])
df
# Out:
#    Names  Age
# 0    Tom   22
# 1   Nick   25
# 2  Julia   22

# %%
data1=[{'a':1, 'b':2 ,'c':3},
      {'a':4, 'b':5, 'c':6}]
df1=pd.DataFrame(data1)
df1
# Out:
#    a  b  c
# 0  1  2  3
# 1  4  5  6

# %%
name=['Ashu','Ravi','Krishna', 'Ashutosh']
age=[10,20,21,22,23]
nameage=list(zip(name,age))
nameage
df2=pd.DataFrame(nameage, columns=['Name','Age'])
df2
# Out:
#        Name  Age
# 0      Ashu   10
# 1      Ravi   20
# 2   Krishna   21
# 3  Ashutosh   22

# %%
data3 = pd.read_csv("https://media.geeksforgeeks.org/wp-content/uploads/nba.csv") 
bottom = data3.tail() 
bottom
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
data3 = pd.read_csv("https://media.geeksforgeeks.org/wp-content/uploads/nba.csv") 
top = data3.head(25) 
top
# Out:
#                        Name            Team  Number Position   Age Height  \
# 0             Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2
# 1               Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6
# 2              John Holland  Boston Celtics    30.0       SG  27.0    6-5
# 3               R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5
# 4             Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10
# 5              Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9
# 6             Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8
# 7              Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0
# 8              Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2
# 9              Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4
# 10          Jared Sullinger  Boston Celtics     7.0        C  24.0    6-9
# 11            Isaiah Thomas  Boston Celtics     4.0       PG  27.0    5-9
# ...

# %%
#Working with date
from datetime import date
d=date(2025,2,3)
print(d)
type(d)
# Out:
# 2025-02-03
# datetime.date

# %%
data3 = pd.read_csv("https://media.geeksforgeeks.org/wp-content/uploads/nba.csv") 
df=data3.copy()
df.iloc[0, :]
# Out:
# Name         Avery Bradley
# Team        Boston Celtics
# Number                 0.0
# Position                PG
# Age                   25.0
# Height                 6-2
# Weight               180.0
# College              Texas
# Salary           7730337.0
# Name: 0, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
df.describe()
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
df.head(25)
# Out:
#                        Name            Team  Number Position   Age Height  \
# 0             Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2
# 1               Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6
# 2              John Holland  Boston Celtics    30.0       SG  27.0    6-5
# 3               R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5
# 4             Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10
# 5              Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9
# 6             Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8
# 7              Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0
# 8              Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2
# 9              Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4
# 10          Jared Sullinger  Boston Celtics     7.0        C  24.0    6-9
# 11            Isaiah Thomas  Boston Celtics     4.0       PG  27.0    5-9
# ...

# %%
df.drop(['Team', 'College'],inplace=True, axis=1)

# %%
df
# Out:
#               Name  Number Position   Age Height  Weight     Salary
# 0    Avery Bradley     0.0       PG  25.0    6-2   180.0  7730337.0
# 1      Jae Crowder    99.0       SF  25.0    6-6   235.0  6796117.0
# 2     John Holland    30.0       SG  27.0    6-5   205.0        NaN
# 3      R.J. Hunter    28.0       SG  22.0    6-5   185.0  1148640.0
# 4    Jonas Jerebko     8.0       PF  29.0   6-10   231.0  5000000.0
# ..             ...     ...      ...   ...    ...     ...        ...
# 453   Shelvin Mack     8.0       PG  26.0    6-3   203.0  2433333.0
# 454      Raul Neto    25.0       PG  24.0    6-1   179.0   900000.0
# 455   Tibor Pleiss    21.0        C  26.0    7-3   256.0  2900000.0
# 456    Jeff Withey    24.0        C  26.0    7-0   231.0   947276.0
# 457            NaN     NaN      NaN   NaN    NaN     NaN        NaN
#
# [458 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Number    457 non-null    float64
#  2   Position  457 non-null    object
#  3   Age       457 non-null    float64
#  4   Height    457 non-null    object
#  5   Weight    457 non-null    float64
#  6   Salary    446 non-null    float64
# dtypes: float64(4), object(3)
# memory usage: 25.2+ KB

# %%
median_salary = df['Salary'].median()
df['Salary'] = df['Salary'].fillna(median_salary)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Number    457 non-null    float64
#  2   Position  457 non-null    object
#  3   Age       457 non-null    float64
#  4   Height    457 non-null    object
#  5   Weight    457 non-null    float64
#  6   Salary    458 non-null    float64
# dtypes: float64(4), object(3)
# memory usage: 25.2+ KB

# %%
df.dropna()
# Out:
#               Name  Number Position   Age Height  Weight     Salary
# 0    Avery Bradley     0.0       PG  25.0    6-2   180.0  7730337.0
# 1      Jae Crowder    99.0       SF  25.0    6-6   235.0  6796117.0
# 2     John Holland    30.0       SG  27.0    6-5   205.0  2839073.0
# 3      R.J. Hunter    28.0       SG  22.0    6-5   185.0  1148640.0
# 4    Jonas Jerebko     8.0       PF  29.0   6-10   231.0  5000000.0
# ..             ...     ...      ...   ...    ...     ...        ...
# 452     Trey Lyles    41.0       PF  20.0   6-10   234.0  2239800.0
# 453   Shelvin Mack     8.0       PG  26.0    6-3   203.0  2433333.0
# 454      Raul Neto    25.0       PG  24.0    6-1   179.0   900000.0
# 455   Tibor Pleiss    21.0        C  26.0    7-3   256.0  2900000.0
# 456    Jeff Withey    24.0        C  26.0    7-0   231.0   947276.0
#
# [457 rows x 7 columns]

# %%
df.dropna()
# Out:
#               Name  Number Position   Age Height  Weight     Salary
# 0    Avery Bradley     0.0       PG  25.0    6-2   180.0  7730337.0
# 1      Jae Crowder    99.0       SF  25.0    6-6   235.0  6796117.0
# 2     John Holland    30.0       SG  27.0    6-5   205.0  2839073.0
# 3      R.J. Hunter    28.0       SG  22.0    6-5   185.0  1148640.0
# 4    Jonas Jerebko     8.0       PF  29.0   6-10   231.0  5000000.0
# ..             ...     ...      ...   ...    ...     ...        ...
# 452     Trey Lyles    41.0       PF  20.0   6-10   234.0  2239800.0
# 453   Shelvin Mack     8.0       PG  26.0    6-3   203.0  2433333.0
# 454      Raul Neto    25.0       PG  24.0    6-1   179.0   900000.0
# 455   Tibor Pleiss    21.0        C  26.0    7-3   256.0  2900000.0
# 456    Jeff Withey    24.0        C  26.0    7-0   231.0   947276.0
#
# [457 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Number    457 non-null    float64
#  2   Position  457 non-null    object
#  3   Age       457 non-null    float64
#  4   Height    457 non-null    object
#  5   Weight    457 non-null    float64
#  6   Salary    458 non-null    float64
# dtypes: float64(4), object(3)
# memory usage: 25.2+ KB

# %%
df.head(25)
# Out:
#                        Name  Number Position   Age Height  Weight      Salary
# 0             Avery Bradley     0.0       PG  25.0    6-2   180.0   7730337.0
# 1               Jae Crowder    99.0       SF  25.0    6-6   235.0   6796117.0
# 2              John Holland    30.0       SG  27.0    6-5   205.0   2839073.0
# 3               R.J. Hunter    28.0       SG  22.0    6-5   185.0   1148640.0
# 4             Jonas Jerebko     8.0       PF  29.0   6-10   231.0   5000000.0
# 5              Amir Johnson    90.0       PF  29.0    6-9   240.0  12000000.0
# 6             Jordan Mickey    55.0       PF  21.0    6-8   235.0   1170960.0
# 7              Kelly Olynyk    41.0        C  25.0    7-0   238.0   2165160.0
# 8              Terry Rozier    12.0       PG  22.0    6-2   190.0   1824360.0
# 9              Marcus Smart    36.0       PG  22.0    6-4   220.0   3431040.0
# 10          Jared Sullinger     7.0        C  24.0    6-9   260.0   2569260.0
# ...

# %%
df = df.drop(df.index[-1])

# %%
df.tail(25)
# Out:
#                  Name  Number Position   Age Height  Weight      Salary
# 432  Maurice Harkless     4.0       SF  23.0    6-9   215.0   2894059.0
# 433  Gerald Henderson     9.0       SG  28.0    6-5   215.0   6000000.0
# 434       Chris Kaman    35.0        C  34.0    7-0   265.0   5016000.0
# 435    Meyers Leonard    11.0       PF  24.0    7-1   245.0   3075880.0
# 436    Damian Lillard     0.0       PG  25.0    6-3   195.0   4236287.0
# 437     C.J. McCollum     3.0       SG  24.0    6-4   200.0   2525160.0
# 438      Luis Montero    44.0       SG  23.0    6-7   185.0    525093.0
# 439     Mason Plumlee    24.0        C  26.0   6-11   235.0   1415520.0
# 440     Brian Roberts     2.0       PG  30.0    6-1   173.0   2854940.0
# 441       Noah Vonleh    21.0       PF  20.0    6-9   240.0   2637720.0
# 442     Trevor Booker    33.0       PF  28.0    6-8   228.0   4775000.0
# 443        Trey Burke     3.0       PG  23.0    6-1   191.0   2658240.0
# ...

# %%
df.to_csv('Emp.csv', index=False)

# %%
dataemp = pd.read_csv('Emp.csv')
dataemp
# Out:
#               Name  Number Position   Age Height  Weight     Salary
# 0    Avery Bradley     0.0       PG  25.0    6-2   180.0  7730337.0
# 1      Jae Crowder    99.0       SF  25.0    6-6   235.0  6796117.0
# 2     John Holland    30.0       SG  27.0    6-5   205.0  2839073.0
# 3      R.J. Hunter    28.0       SG  22.0    6-5   185.0  1148640.0
# 4    Jonas Jerebko     8.0       PF  29.0   6-10   231.0  5000000.0
# ..             ...     ...      ...   ...    ...     ...        ...
# 452     Trey Lyles    41.0       PF  20.0   6-10   234.0  2239800.0
# 453   Shelvin Mack     8.0       PG  26.0    6-3   203.0  2433333.0
# 454      Raul Neto    25.0       PG  24.0    6-1   179.0   900000.0
# 455   Tibor Pleiss    21.0        C  26.0    7-3   256.0  2900000.0
# 456    Jeff Withey    24.0        C  26.0    7-0   231.0   947276.0
#
# [457 rows x 7 columns]
